# %% [markdown]
# ## 边缘检测Canny
# ![image.png](attachment:5cc26ee8-461a-4bbc-9375-e4f3dc1d5539.png)
# ![image.png](attachment:6b73970f-97f9-49fc-a039-39d4d656cb71.png)
# ![image.png](attachment:575fde77-d7eb-4000-af09-1496cdd1a0ae.png)
# ![image.png](attachment:cac6dc74-9a3f-4b9b-9df3-0afd8cb05fee.png)
# ![image.png](attachment:aed17375-6e84-4d0f-9769-1790d4d99739.png)

# %%
import cv2
import numpy as np

mountain=cv2.imread('./mountain.jpg')

#1.去噪
#2.非极大值抑制
#3.滞后阈值

new1=cv2.Canny(mountain,100,200)
#阈值越小，细节越丰富
new2=cv2.Canny(mountain,64,128)

cv2.imshow('show1',np.hstack((new1,new2)))
cv2.waitKey(0)
cv2.destroyAllWindows()
